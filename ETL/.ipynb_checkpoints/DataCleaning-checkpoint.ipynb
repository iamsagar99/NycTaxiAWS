# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Using cached pyspark-3.5.5-py2.py3-none-any.whl
# Collecting py4j==0.10.9.7 (from pyspark)
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.9
#     Uninstalling py4j-0.10.9.9:
#       Successfully uninstalled py4j-0.10.9.9
# Successfully installed py4j-0.10.9.7 pyspark-3.5.5

# %%
! spark-submit --packages org.apache.hadoop:hadoop-aws:3.3.2,com.amazonaws:aws-java-sdk:1.12.262 mainkam.py
# Out:
# :: loading settings :: url = jar:file:/opt/conda/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/sagemaker-user/.ivy2/cache
# The jars for the packages stored in: /home/sagemaker-user/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-defef028-3f39-4996-ae1a-97bc1c1e46af;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.2 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.1026 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found com.amazonaws#aws-java-sdk;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iamrolesanywhere;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-core;1.12.262 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found software.amazon.ion#ion-java;1.0.2 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.6.1 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.6 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.6 in central
# 	found com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.12.6 in central
# 	found joda-time#joda-time;2.8.1 in central
# 	found com.amazonaws#jmespath-java;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-redshiftserverless;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-connectcampaign;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mainframemodernization;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-emrserverless;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-chimesdkmediapipelines;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ivschat;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pinpointsmsvoicev2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-gamesparks;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-billingconductor;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-keyspaces;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-amplifyuibuilder;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-backupgateway;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-workspacesweb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iottwinmaker;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-recyclebin;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatchrum;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatchevidently;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-inspector2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-migrationhubrefactorspaces;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appconfigdata;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-drs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-migrationhubstrategyrecommendations;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-resiliencehub;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-chimesdkmeetings;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-panorama;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-managedgrafana;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudcontrolapi;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-account;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-voiceid;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-connectwisdom;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kafkaconnect;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-opensearch;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-memorydb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-snowdevicemanagement;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-chimesdkidentity;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-chimesdkmessaging;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-route53recoverycluster;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-route53recoverycontrolconfig;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-route53recoveryreadiness;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-proton;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-apprunner;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-applicationcostprofiler;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ssmcontacts;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ssmincidents;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-finspacedata;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-finspace;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-nimblestudio;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lookoutequipment;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mgn;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lookoutmetrics;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-fis;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lexmodelsv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lexruntimev2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-wellarchitected;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-location;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotdeviceadvisor;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotfleethub;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotwireless;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-greengrassv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-prometheus;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-auditmanager;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-healthlake;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sagemakeredgemanager;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-emrcontainers;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-customerprofiles;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lookoutforvision;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-connectcontactlens;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-amplifybackend;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ecrpublic;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appintegrations;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sagemakerfeaturestoreruntime;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-devopsguru;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mwaa;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-networkfirewall;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appregistry;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-gluedatabrew;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-s3outposts;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-timestreamquery;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-timestreamwrite;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ssoadmin;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-redshiftdataapi;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appflow;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-identitystore;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-braket;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ivs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-honeycode;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codeartifact;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-macie2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotsitewise;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-synthetics;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codestarconnections;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-detective;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kinesisvideosignalingchannels;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ebs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-augmentedairuntime;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-outposts;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codeguruprofiler;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codegurureviewer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-frauddetector;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kendra;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-networkmanager;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-computeoptimizer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-accessanalyzer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-schemas;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-imagebuilder;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticinference;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotsecuretunneling;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appconfig;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-wafv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-connectparticipant;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-migrationhubconfig;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-dataexchange;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sesv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-marketplacecatalog;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ssooidc;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sso;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-savingsplans;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codestarnotifications;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-workmailmessageflow;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-qldbsession;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-qldb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-forecastquery;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-forecast;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lakeformation;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-eventbridge;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ec2instanceconnect;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-applicationinsights;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-servicequotas;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-personalizeevents;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-personalize;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-personalizeruntime;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ioteventsdata;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotevents;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotthingsgraph;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-groundstation;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediapackagevod;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-managedblockchain;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-textract;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-worklink;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-backup;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-docdb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-apigatewayv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-apigatewaymanagementapi;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kafka;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appmesh;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-licensemanager;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-securityhub;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-fsx;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediaconnect;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kinesisanalyticsv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-comprehendmedical;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-globalaccelerator;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-transfer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-datasync;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-robomaker;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-amplify;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-quicksight;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-rdsdata;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-route53resolver;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ram;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-s3control;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pinpointsmsvoice;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pinpointemail;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-chime;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-signer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-dlm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-macie;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-eks;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediatailor;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-neptune;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pi;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickprojects;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iot1clickdevices;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotanalytics;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-acmpca;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-secretsmanager;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-fms;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-connect;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-transcribe;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-autoscalingplans;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-workmail;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-servicediscovery;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloud9;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-alexaforbusiness;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroups;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-comprehend;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-translate;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sagemaker;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iotjobsdataplane;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sagemakerruntime;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kinesisvideo;1.12.262 in central
# 	found io.netty#netty-codec-http;4.1.77.Final in central
# 	found io.netty#netty-common;4.1.77.Final in central
# 	found io.netty#netty-buffer;4.1.77.Final in central
# 	found io.netty#netty-transport;4.1.77.Final in central
# 	found io.netty#netty-resolver;4.1.77.Final in central
# 	found io.netty#netty-codec;4.1.77.Final in central
# 	found io.netty#netty-handler;4.1.77.Final in central
# 	found com.amazonaws#aws-java-sdk-appsync;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-guardduty;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mq;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediaconvert;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediastore;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediastoredata;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-medialive;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mediapackage;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-costexplorer;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pricing;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mobile;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsmv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-glue;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-migrationhub;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-dax;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-greengrass;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-athena;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-marketplaceentitlement;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codestar;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lexmodelbuilding;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-pinpoint;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-xray;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-opsworkscm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-support;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-simpledb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-servicecatalog;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-servermigration;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-simpleworkflow;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-storagegateway;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-route53;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-importexport;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sts;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sqs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-rds;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-redshift;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticbeanstalk;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-glacier;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-sns;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iam;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-datapipeline;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancing;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticloadbalancingv2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-emr;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticache;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elastictranscoder;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ec2;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-dynamodb;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-budgets;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudtrail;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatch;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-logs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-events;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidentity;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cognitosync;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-directconnect;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudformation;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudfront;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-clouddirectory;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-kinesis;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-opsworks;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ses;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-autoscaling;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudsearch;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudwatchmetrics;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codedeploy;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codepipeline;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-config;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lambda;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ecs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ecr;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cloudhsm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-ssm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-workspaces;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-machinelearning;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-directory;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-efs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codecommit;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-devicefarm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-elasticsearch;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-waf;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-inspector;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-iot;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-api-gateway;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-acm;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-gamelift;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-dms;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-cognitoidp;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-discovery;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-applicationautoscaling;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-snowball;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-rekognition;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-polly;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lightsail;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-stepfunctions;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-health;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-costandusagereport;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-codebuild;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-appstream;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-shield;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-batch;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-lex;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-organizations;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-workdocs;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-models;1.12.262 in central
# 	found com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 in central
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sd
1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-kinesisvideosignalingchannels;1.12.262!aws-java-sdk-kinesisvideosignalingchannels.jar (24ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-ebs/1.12.262/aws-java-sdk-ebs-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-ebs;1.12.262!aws-java-sdk-ebs.jar (24ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-augmentedairuntime/1.12.262/aws-java-sdk-augmentedairuntime-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-augmentedairuntime;1.12.262!aws-java-sdk-augmentedairuntime.jar (24ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-outposts/1.12.262/aws-java-sdk-outposts-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-outposts;1.12.262!aws-java-sdk-outposts.jar (25ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-codeguruprofiler/1.12.262/aws-java-sdk-codeguruprofiler-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-codeguruprofiler;1.12.262!aws-java-sdk-codeguruprofiler.jar (29ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-codegurureviewer/1.12.262/aws-java-sdk-codegurureviewer-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-codegurureviewer;1.12.262!aws-java-sdk-codegurureviewer.jar (24ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-frauddetector/1.12.262/aws-java-sdk-frauddetector-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-frauddetector;1.12.262!aws-java-sdk-frauddetector.jar (31ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-kendra/1.12.262/aws-java-sdk-kendra-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-kendra;1.12.262!aws-java-sdk-kendra.jar (33ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-networkmanager/1.12.262/aws-java-sdk-networkmanager-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-networkmanager;1.12.262!aws-java-sdk-networkmanager.jar (33ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-computeoptimizer/1.12.262/aws-java-sdk-computeoptimizer-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-computeoptimizer;1.12.262!aws-java-sdk-computeoptimizer.jar (23ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-accessanalyzer/1.12.262/aws-java-sdk-accessanalyzer-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-accessanalyzer;1.12.262!aws-java-sdk-accessanalyzer.jar (25ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-schemas/1.12.262/aws-java-sdk-schemas-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-schemas;1.12.262!aws-java-sdk-schemas.jar (25ms)
# downloading https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-imagebuilder/1.12.262/aws-java-sdk-imagebuilder-1.12.262.jar ...
# 	[SUCCESSFUL ] com.amazonaws#aws-java-sdk-imagebuilder;1.12.262!aws-java-sdk-imagebuilder.jar (30ms)
# ...
# 	com.amazonaws#aws-java-sdk-health;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-healthlake;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-honeycode;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iam;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iamrolesanywhere;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-identitystore;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-imagebuilder;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-importexport;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-inspector;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-inspector2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickdevices;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iot1clickprojects;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotanalytics;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotdeviceadvisor;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotevents;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ioteventsdata;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotfleethub;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotjobsdataplane;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotsecuretunneling;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotsitewise;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotthingsgraph;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iottwinmaker;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-iotwireless;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ivs;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ivschat;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kafka;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kafkaconnect;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kendra;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-keyspaces;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesis;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesisanalyticsv2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesisvideo;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kinesisvideosignalingchannels;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-kms;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lakeformation;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lambda;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lex;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lexmodelbuilding;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lexmodelsv2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lexruntimev2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-licensemanager;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lightsail;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-location;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-logs;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lookoutequipment;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lookoutforvision;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-lookoutmetrics;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-machinelearning;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-macie;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-macie2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mainframemodernization;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-managedblockchain;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-managedgrafana;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacecatalog;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacecommerceanalytics;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplaceentitlement;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-marketplacemeteringservice;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mechanicalturkrequester;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediaconnect;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediaconvert;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-medialive;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediapackage;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediapackagevod;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastore;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediastoredata;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mediatailor;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-memorydb;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mgn;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhub;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhubconfig;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhubrefactorspaces;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-migrationhubstrategyrecommendations;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mobile;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-models;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mq;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-mwaa;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-neptune;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-networkfirewall;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-networkmanager;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-nimblestudio;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-opensearch;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworks;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-opsworkscm;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-organizations;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-outposts;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-panorama;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-personalize;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-personalizeevents;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-personalizeruntime;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pi;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpoint;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpointemail;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpointsmsvoice;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pinpointsmsvoicev2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-polly;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-pricing;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-prometheus;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-proton;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-qldb;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-qldbsession;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-quicksight;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ram;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-rds;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-rdsdata;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-recyclebin;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshift;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshiftdataapi;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-redshiftserverless;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-rekognition;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-resiliencehub;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroups;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-resourcegroupstaggingapi;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-robomaker;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53recoverycluster;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53recoverycontrolconfig;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53recoveryreadiness;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-route53resolver;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3control;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-s3outposts;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemaker;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakeredgemanager;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakerfeaturestoreruntime;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sagemakerruntime;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-savingsplans;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-schemas;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-secretsmanager;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-securityhub;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-serverlessapplicationrepository;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-servermigration;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicecatalog;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicediscovery;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-servicequotas;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ses;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sesv2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-shield;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-signer;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpledb;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-snowball;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-snowdevicemanagement;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sns;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sqs;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssm;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssmcontacts;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssmincidents;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sso;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssoadmin;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-ssooidc;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-stepfunctions;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-storagegateway;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-sts;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-support;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-swf-libraries;1.11.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-synthetics;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-textract;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-timestreamquery;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-timestreamwrite;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-transcribe;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-transfer;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-translate;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-voiceid;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-waf;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-wafv2;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-wellarchitected;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-workdocs;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-worklink;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-workmail;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-workmailmessageflow;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-workspaces;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-workspacesweb;1.12.262 from central in [default]
# 	com.amazonaws#aws-java-sdk-xray;1.12.262 from central in [default]
# 	com.amazonaws#jmespath-java;1.12.262 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.6 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.6 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.6.1 from central in [default]
# 	com.fasterxml.jackson.dataformat#jackson-dataformat-cbor;2.12.6 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	io.netty#netty-buffer;4.1.77.Final from central in [default]
# 	io.netty#netty-codec;4.1.77.Final from central in [default]
# 	io.netty#netty-codec-http;4.1.77.Final from central in [default]
# 	io.netty#netty-common;4.1.77.Final from central in [default]
# 	io.netty#netty-handler;4.1.77.Final from central in [default]
# 	io.netty#netty-resolver;4.1.77.Final from central in [default]
# 	io.netty#netty-transport;4.1.77.Final from central in [default]
# 	joda-time#joda-time;2.8.1 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.2 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	software.amazon.ion#ion-java;1.0.2 from central in [default]
# 	:: evicted modules:
# 	commons-logging#commons-logging;1.2 by [commons-logging#commons-logging;1.1.3] in [default]
# 	commons-codec#commons-codec;1.11 by [commons-codec#commons-codec;1.15] in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.6 by [com.fasterxml.jackson.core#jackson-databind;2.12.6.1] in [default]
# 	com.amazonaws#aws-java-sdk-simpleworkflow;1.11.22 by [com.amazonaws#aws-java-sdk-simpleworkflow;1.12.262] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  331  |  321  |  321  |   4   ||  327  |  321  |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-defef028-3f39-4996-ae1a-97bc1c1e46af
# 	confs: [default]
# 	321 artifacts copied, 6 already retrieved (491148kB/383ms)
# 25/03/10 15:19:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# python3: can't open file '/home/sagemaker-user/src/aws/ETL/mainkam.py': [Errno 2] No such file or directory
# 25/03/10 15:19:12 INFO ShutdownHookManager: Shutdown hook called
# 25/03/10 15:19:12 INFO ShutdownHookManager: Deleting directory /tmp/spark-b23a6fb8-2165-407c-b730-ffb8c8d1d58a

# %%
from pyspark.sql import SparkSession

# %%
from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
access_key = "AKIAUYIPVUU7JBVMHPUZ"
secret_key = "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"

# %%
spark = SparkSession.builder \
    .appName("DataCleaning") \
    .config("spark.hadoop.fs.s3a.access.key", access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", secret_key) \
    .config("spark.hadoop.fs.s3a.endpoint", "s3.amazonaws.com") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.2,com.amazonaws:aws-java-sdk-bundle:1.12.262") \
    .getOrCreate()

# %%
ride_info_path = "s3a://nyc-taxi-dataset-360/nyc-taxi-orig-cleaned-split-parquet-per-year-multiple-files/ride-info/"

ri_df = spark.read.parquet(ride_info_path)
# Out:
# 25/03/10 15:19:40 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
ri_df.show(5)
# Out:
# 25/03/10 15:19:45 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# +-------------+---------+---------------+-------------------+-------------------+-------------+------------+------------------+----+
# |      ride_id|vendor_id|passenger_count|          pickup_at|         dropoff_at|trip_distance|rate_code_id|store_and_fwd_flag|year|
# +-------------+---------+---------------+-------------------+-------------------+-------------+------------+------------------+----+
# |1357210086948|        2|              1|2017-04-27 21:37:17|2017-04-27 21:41:24|         0.71|           1|                 N|2017|
# | 816044877583|        1|              3|2017-08-05 18:48:55|2017-08-05 18:55:04|          0.5|           1|                 N|2017|
# |1357210086949|        1|              1|2017-10-25 07:00:32|2017-10-25 07:08:25|          1.2|           1|                 N|2017|
# | 816044877584|        2|              1|2017-01-02 15:02:23|2017-01-02 15:49:06|         15.7|           1|                 N|2017|
# |1357210086950|        1|              2|2017-04-27 21:37:18|2017-04-27 21:43:00|          0.8|           1|                 N|2017|
# +-------------+---------+---------------+-------------------+-------------------+-------------+------------+------------------+----+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import TimestampType

filtered_df = ri_df.filter(
    (F.col('passenger_count').between(1, 6)) &  
    (F.col('pickup_at') < F.col('dropoff_at')) &  
    (F.col('pickup_at') > F.lit('2012-01-01 00:00:00').cast(TimestampType())) &  
    (F.col('dropoff_at') < F.current_timestamp()) &  
    (F.col('dropoff_at') - F.col('pickup_at') < F.expr('INTERVAL 1 DAY')) &  
    (F.col('trip_distance').between(0.1486583893482752, 24.393604281121316)) 
)

# %%
filtered_df.cache()
# Out:
# DataFrame[ride_id: bigint, vendor_id: int, passenger_count: tinyint, pickup_at: timestamp, dropoff_at: timestamp, trip_distance: float, rate_code_id: int, store_and_fwd_flag: string, year: int]

# %%
filtered_df.show(5)
# Out:
# 25/03/10 15:24:28 WARN BlockManager: Block rdd_10_4 could not be removed as it was not found on disk or in memory
# 25/03/10 15:24:28 WARN BlockManager: Block rdd_10_2 could not be removed as it was not found on disk or in memory
# 25/03/10 15:24:28 WARN BlockManager: Block rdd_10_1 could not be removed as it was not found on disk or in memory
# 25/03/10 15:24:28 ERROR Executor: Exception in task 4.0 in stage 2.0 (TID 6)
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 ERROR Executor: Exception in task 1.0 in stage 2.0 (TID 3)
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 ERROR Executor: Exception in task 2.0 in stage 2.0 (TID 4)
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#131,Executor task launch worker for task 1.0 in stage 2.0 (TID 3),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#132,Executor task launch worker for task 2.0 in stage 2.0 (TID 4),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 ERROR SparkUncaughtExceptionHandler: [Container in shutdown] Uncaught exception in thread Thread[#134,Executor task launch worker for task 4.0 in stage 2.0 (TID 6),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
# 25/03/10 15:24:28 WARN TaskSetManager: Lost task 1.0 in stage 2.0 (TID 3) (default executor driver): java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.<init>(HeapByteBuffer.java:71)
# 	at java.base/java.nio.ByteBuffer.allocate(ByteBuffer.java:394)
# 	at org.apache.parquet.bytes.HeapByteBufferAllocator.allocate(HeapByteBufferAllocator.java:32)
# 	at org.apache.parquet.hadoop.ParquetFileReader$ConsecutivePartList.readAll(ParquetFileReader.java:1842)
# 	at org.apache.parquet.hadoop.ParquetFileReader.internalReadRowGroup(ParquetFileReader.java:990)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextRowGroup(ParquetFileReader.java:940)
# 	at org.apache.parquet.hadoop.ParquetFileReader.readNextFilteredRowGroup(ParquetFileReader.java:1100)
# 	at org.apache.spark.sql.execution.datasources.parquet.SpecificParquetRecordReaderBase$ParquetRowGroupReaderImpl.readNextRowGroup(SpecificParquetRecordReaderBase.java:287)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.checkEndOfRowGroup(VectorizedParquetRecordReader.java:418)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:335)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:233)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:286)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:131)
# 	at org.apache.spark.sql.execution.FileSourceScanExec$$anon$1.hasNext(DataSourceScanExec.scala:593)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.columnartorow_nextBatch_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage1.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenEvaluatorFactory$WholeStageCodegenPartitionEvaluator$$anon$1.hasNext(WholeStageCodegenEvaluatorFactory.scala:43)
# 	at org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer$$anon$1.hasNext(InMemoryRelation.scala:119)
# 	at org.apache.spark.sql.execution.columnar.CachedRDDBuilder$$anon$2.hasNext(InMemoryRelation.scala:288)
# 	at org.apache.spark.storage.memory.MemoryStore.putIterator(MemoryStore.scala:223)
# 	at org.apache.spark.storage.memory.MemoryStore.putIteratorAsValues(MemoryStore.scala:302)
# 	at org.apache.spark.storage.BlockManager.$anonfun$doPutIterator$1(BlockManager.scala:1597)
# 	at org.apache.spark.storage.BlockManager$$Lambda/0x00007f4133bbf530.apply(Unknown Source)
# 	at org.apache.spark.storage.BlockManager.org$apache$spark$storage$BlockManager$$doPut(BlockManager.scala:1524)
# 	at org.apache.spark.storage.BlockManager.doPutIterator(BlockManager.scala:1588)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdate(BlockManager.scala:1389)
# 	at org.apache.spark.storage.BlockManager.getOrElseUpdateRDDBlock(BlockManager.scala:1343)
# 	at org.apache.spark.rdd.RDD.getOrCompute(RDD.scala:379)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:329)
#
# 25/03/10 15:24:28 ERROR TaskSetManager: Task 1 in stage 2.0 failed 1 times; aborting job
# 25/03/10 15:24:28 ERROR Inbox: Ignoring error
# java.util.concurrent.RejectedExecutionException: Task org.apache.spark.executor.Executor$TaskRunner@c80c3de rejected from java.util.concurrent.ThreadPoolExecutor@3949348d[Shutting down, pool size = 7, active threads = 7, queued tasks = 0, completed tasks = 3]
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$AbortPolicy.rejectedExecution(ThreadPoolExecutor.java:2081)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.reject(ThreadPoolExecutor.java:841)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.execute(ThreadPoolExecutor.java:1376)
# 	at org.apache.spark.executor.Executor.launchTask(Executor.scala:363)
# 	at org.apache.spark.scheduler.local.LocalEndpoint.$anonfun$reviveOffers$1(LocalSchedulerBackend.scala:93)
# 	at org.apache.spark.scheduler.local.LocalEndpoint.$anonfun$reviveOffers$1$adapted(LocalSchedulerBackend.scala:91)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at scala.collection.IterableLike.foreach(IterableLike.scala:74)
# 	at scala.collection.IterableLike.foreach$(IterableLike.scala:73)
# 	at scala.collection.AbstractIterable.foreach(Iterable.scala:56)
# 	at org.apache.spark.scheduler.local.LocalEndpoint.reviveOffers(LocalSchedulerBackend.scala:91)
# 	at org.apache.spark.scheduler.local.LocalEndpoint$$anonfun$receive$1.applyOrElse(LocalSchedulerBackend.scala:74)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:115)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 25/03/10 15:24:28 WARN BlockManager: Putting block rdd_10_6 failed due to exception org.apache.spark.SparkException: Encountered error while reading file s3a://nyc-taxi-dataset-360/nyc-taxi-orig-cleaned-split-parquet-per-year-multiple-files/ride-info/year=2017/part-00223-tid-1765312908850392118-41a0b846-936e-472e-93be-0fdee7cbe73f-3307-1.c000.parquet. Details:.
# 25/03/10 15:24:28 WARN BlockManager: Putting block rdd_10_5 failed due to exception org.apache.spark.SparkException: Encountered error while reading file s3a://nyc-taxi-dataset-360/nyc-taxi-orig-cleaned-split-parquet-per-year-multiple-files/ride-info/year=2017/part-00216-tid-1765312908850392118-41a0b846-936e-472e-93be-0fdee7cbe73f-3300-1.c000.parquet. Details:.
# 25/03/10 15:24:28 WARN BlockManager: Block rdd_10_6 was not removed normally.
# 25/03/10 15:24:28 WARN BlockManager: Block rdd_10_5 was not removed normally.
# 25/03/10 15:24:28 ERROR TaskContextImpl: Error in TaskCompletionListener
# org.apache.spark.SparkException: Block broadcast_3 does not exist
# 	at org.apache.spark.errors.SparkCoreErrors$.blockDoesNotExistError(SparkCoreErrors.scala:318)
# 	at org.apache.spark.storage.BlockInfoManager.blockInfo(BlockInfoManager.scala:269)
# 	at org.apache.spark.storage.BlockInfoManager.unlock(BlockInfoManager.scala:390)
# 	at org.apache.spark.storage.BlockManager.releaseLock(BlockManager.scala:1309)
# 	at org.apache.spark.broadcast.TorrentBroadcast.$anonfun$releaseBlockManagerLock$1(TorrentBroadcast.scala:319)
# 	at org.apache.spark.broadcast.TorrentBroadcast.$anonfun$releaseBlockManagerLock$1$adapted(TorrentBroadcast.scala:319)
# 	at org.apache.spark.TaskContext$$anon$1.onTaskCompletion(TaskContext.scala:137)
# 	at org.apache.spark.TaskContextImpl.$anonfun$invokeTaskCompletionListeners$1(TaskContextImpl.scala:144)
# 	at org.apache.spark.TaskContextImpl.$anonfun$invokeTaskCompletionListeners$1$adapted(TaskContextImpl.scala:144)
# 	at org.apache.spark.TaskContextImpl.invokeListeners(TaskContextImpl.scala:199)
# 	at org.apache.spark.TaskContextImpl.invokeTaskCompletionListeners(TaskContextImpl.scala:144)
# 	at org.apache.spark.TaskContextImpl.markTaskCompleted(TaskContextImpl.scala:137)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:177)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 25/03/10 15:24:28 ERROR Utils: Uncaught exception in thread Executor task launch worker for task 6.0 in stage 2.0 (TID 8)
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.SparkEnv.blockManager()" because the return value of "org.apache.spark.SparkEnv$.get()" is null
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:146)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:144)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 25/03/10 15:24:28 ERROR Utils: Uncaught exception in thread Executor task launch worker for task 5.0 in stage 2.0 (TID 7)
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.SparkEnv.blockManager()" because the return value of "org.apache.spark.SparkEnv$.get()" is null
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:146)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:144)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 25/03/10 15:24:28 ERROR Executor: Exception in task 6.0 in stage 2.0 (TID 8): Block rdd_10_6 does not exist
# 25/03/10 15:24:28 ERROR Executor: Exception in task 5.0 in stage 2.0 (TID 7): Block rdd_10_5 does not exist
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[22], line 1
# ----> 1 filtered_df.show(5)
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/dataframe.py:947, in DataFrame.show(self, n, truncate, vertical)
#     888 """Prints the first ``n`` rows to the console.
#     889
#     890 .. versionadded:: 1.3.0
#    (...)
#     945 name | Bob
#     946 """
# --> 947 print(self._show_string(n, truncate, vertical))
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/sql/dataframe.py:965, in DataFrame._show_string(self, n, truncate, vertical)
#     964 if isinstance(truncate, bool) and truncate:
# --> 965     return self._jdf.showString(n, 20, vertical)
#     966 else:
#
# File /opt/conda/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File /opt/conda/lib/python3.11/site-packages/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     178 try:
# --> 179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
#
# File /opt/conda/lib/python3.11/site-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#
# <class 'str'>: (<class 'ConnectionRefusedError'>, ConnectionRefusedError(111, 'Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2179, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2176         traceback.print_exc()
#    2177         return None
# -> 2179     self._showtraceback(etype, value, stb)
#    2180 if self.call_pdb:
#    2181     # drop into debugger
#    2182     self.debugger(force=True)
#
# File /opt/conda/lib/python3.11/site-packages/ipykernel/zmqshell.py:559, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     553 sys.stdout.flush()
#     554 sys.stderr.flush()
#     556 exc_content = {
#     557     "traceback": stb,
#     558     "ename": str(etype.__name__),
# --> 559     "evalue": str(evalue),
#     560 }
#     562 dh = self.displayhook
#     563 # Send exception info over pub socket for other clients than the caller
#     564 # to pick up
#
# File /opt/conda/lib/python3.11/site-packages/py4j/protocol.py:471, in Py4JJavaError.__str__(self)
#     469 def __str__(self):
#     470     gateway_client = self.java_exception._gateway_client
# --> 471     answer = gateway_client.send_command(self.exception_cmd)
#     472     return_value = get_return_value(answer, gateway_client, None, None)
#     473     # Note: technically this should return a bytestring 'str' rather than
#     474     # unicodes in Python 2; however, it can return unicodes for now.
#     475     # See https://github.com/bartdag/py4j/issues/306 for more details.
#
# File /opt/conda/lib/python3.11/site-packages/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File /opt/conda/lib/python3.11/site-packages/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File /opt/conda/lib/python3.11/site-packages/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File /opt/conda/lib/python3.11/site-packages/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused
